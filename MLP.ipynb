# %%
# importing modules 
import tensorflow as tf 
import numpy as np 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Flatten 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.layers import Activation 
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
gray_scale=255
x_train/=gray_scale
x_test/=gray_scale

# %%
print('feature matrix:',x_train.shape)
print('target matrix:',x_test.shape)
print('feature matrix:',y_train.shape)
print('target matrix:',y_test.shape)
# Out:
# feature matrix: (60000, 28, 28)
# target matrix: (10000, 28, 28)
# feature matrix: (60000,)
# target matrix: (10000,)

# %%
fig,ax=plt.subplots(12,12)
k=0
for i in range (12):
    for j in range(12):
        ax[i][j].imshow(x_train[k].reshape(28,28),aspect='auto')
        
        k+=1
plt.show()

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(512,activation='sigmoid'),
    Dense(256,activation='sigmoid'),
    Dense(10,activation='sigmoid'),
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train, epochs=50,batch_size=2000,validation_split=0.2)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 3s 61ms/step - loss: 1.9380 - accuracy: 0.4681 - val_loss: 1.3602 - val_accuracy: 0.7507
# Epoch 2/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.9779 - accuracy: 0.7955 - val_loss: 0.6510 - val_accuracy: 0.8574
# Epoch 3/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.5591 - accuracy: 0.8634 - val_loss: 0.4357 - val_accuracy: 0.8911
# Epoch 4/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.4162 - accuracy: 0.8904 - val_loss: 0.3544 - val_accuracy: 0.9057
# Epoch 5/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.3539 - accuracy: 0.9031 - val_loss: 0.3156 - val_accuracy: 0.9145
# Epoch 6/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3185 - accuracy: 0.9106 - val_loss: 0.2893 - val_accuracy: 0.9199
# Epoch 7/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2942 - accuracy: 0.9156 - val_loss: 0.2725 - val_accuracy: 0.9238
# Epoch 8/50
# 24/24 [==============================] - 1s 33ms/step - loss: 0.2753 - accuracy: 0.9211 - val_loss: 0.2556 - val_accuracy: 0.9274
# Epoch 9/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2600 - accuracy: 0.9245 - val_loss: 0.2442 - val_accuracy: 0.9298
# Epoch 10/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2471 - accuracy: 0.9285 - val_loss: 0.2353 - val_accuracy: 0.9320
# Epoch 11/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2346 - accuracy: 0.9327 - val_loss: 0.2228 - val_accuracy: 0.9367
# Epoch 12/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2242 - accuracy: 0.9340 - val_loss: 0.2152 - val_accuracy: 0.9392
# Epoch 13/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2132 - accuracy: 0.9379 - val_loss: 0.2072 - val_accuracy: 0.9410
# Epoch 14/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.2033 - accuracy: 0.9406 - val_loss: 0.1985 - val_accuracy: 0.9433
# Epoch 15/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1946 - accuracy: 0.9431 - val_loss: 0.1937 - val_accuracy: 0.9463
# Epoch 16/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1857 - accuracy: 0.9455 - val_loss: 0.1859 - val_accuracy: 0.9482
# Epoch 17/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1769 - accuracy: 0.9483 - val_loss: 0.1793 - val_accuracy: 0.9503
# Epoch 18/50
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1690 - accuracy: 0.9505 - val_loss: 0.1740 - val_accuracy: 0.9513
# Epoch 19/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1620 - accuracy: 0.9535 - val_loss: 0.1695 - val_accuracy: 0.9534
# Epoch 20/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1555 - accuracy: 0.9546 - val_loss: 0.1649 - val_accuracy: 0.9536
# Epoch 21/50
# 24/24 [==============================] - 1s 24ms/step - loss: 0.1489 - accuracy: 0.9566 - val_loss: 0.1598 - val_accuracy: 0.9557
# Epoch 22/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1431 - accuracy: 0.9587 - val_loss: 0.1558 - val_accuracy: 0.9563
# Epoch 23/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1372 - accuracy: 0.9600 - val_loss: 0.1508 - val_accuracy: 0.9580
# Epoch 24/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1308 - accuracy: 0.9623 - val_loss: 0.1462 - val_accuracy: 0.9589
# Epoch 25/50
# 24/24 [==============================] - 1s 30ms/step - loss: 0.1253 - accuracy: 0.9640 - val_loss: 0.1429 - val_accuracy: 0.9595
# Epoch 26/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1195 - accuracy: 0.9657 - val_loss: 0.1406 - val_accuracy: 0.9586
# Epoch 27/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.1162 - accuracy: 0.9666 - val_loss: 0.1363 - val_accuracy: 0.9603
# Epoch 28/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.1101 - accuracy: 0.9689 - val_loss: 0.1319 - val_accuracy: 0.9621
# Epoch 29/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1063 - accuracy: 0.9699 - val_loss: 0.1291 - val_accuracy: 0.9632
# Epoch 30/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1015 - accuracy: 0.9715 - val_loss: 0.1253 - val_accuracy: 0.9643
# Epoch 31/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0967 - accuracy: 0.9727 - val_loss: 0.1245 - val_accuracy: 0.9633
# Epoch 32/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0925 - accuracy: 0.9741 - val_loss: 0.1202 - val_accuracy: 0.9643
# Epoch 33/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0895 - accuracy: 0.9755 - val_loss: 0.1191 - val_accuracy: 0.9654
# Epoch 34/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0857 - accuracy: 0.9764 - val_loss: 0.1156 - val_accuracy: 0.9663
# Epoch 35/50
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0821 - accuracy: 0.9770 - val_loss: 0.1140 - val_accuracy: 0.9661
# Epoch 36/50
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0787 - accuracy: 0.9780 - val_loss: 0.1118 - val_accuracy: 0.9666
# Epoch 37/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0749 - accuracy: 0.9796 - val_loss: 0.1083 - val_accuracy: 0.9682
# Epoch 38/50
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0717 - accuracy: 0.9805 - val_loss: 0.1066 - val_accuracy: 0.9683
# Epoch 39/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0688 - accuracy: 0.9813 - val_loss: 0.1044 - val_accuracy: 0.9691
# Epoch 40/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0658 - accuracy: 0.9820 - val_loss: 0.1050 - val_accuracy: 0.9686
# Epoch 41/50
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0634 - accuracy: 0.9829 - val_loss: 0.1019 - val_accuracy: 0.9703
# Epoch 42/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0605 - accuracy: 0.9836 - val_loss: 0.1008 - val_accuracy: 0.9693
# Epoch 43/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0577 - accuracy: 0.9846 - val_loss: 0.0989 - val_accuracy: 0.9705
# Epoch 44/50
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0554 - accuracy: 0.9854 - val_loss: 0.0983 - val_accuracy: 0.9701
# Epoch 45/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0528 - accuracy: 0.9861 - val_loss: 0.0964 - val_accuracy: 0.9707
# Epoch 46/50
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0506 - accuracy: 0.9868 - val_loss: 0.0947 - val_accuracy: 0.9721
# Epoch 47/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0482 - accuracy: 0.9880 - val_loss: 0.0941 - val_accuracy: 0.9708
# Epoch 48/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0459 - accuracy: 0.9884 - val_loss: 0.0933 - val_accuracy: 0.9712
# Epoch 49/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0446 - accuracy: 0.9889 - val_loss: 0.0920 - val_accuracy: 0.9721
# Epoch 50/50
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0426 - accuracy: 0.9896 - val_loss: 0.0904 - val_accuracy: 0.9722

# %%
results = model.evaluate(x_test, y_test, verbose = 0) 
print('test loss, test acc:', results)
# Out:
# test loss, test acc: [0.08394423872232437, 0.9745000004768372]
